# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_excel("D:/Sample.xlsx")

# %%
df.head()
# Out:
#    SSC Percentage  HSC Percentage  Graduation Percentage  Salary
# 0            85.6            69.7                   60.7   47000
# 1            82.0            62.0                   40.0   25647
# 2            80.0            63.1                   56.1   38100
# 3            76.0            64.0                   59.4   39456
# 4            78.0            69.0                   57.9   41050

# %% [markdown]
# ## Pairplot (One code for all)

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr())

# %% [markdown]
# ## Sorting variables into dependent and independent features

# %%
X = df[["SSC Percentage", "HSC Percentage", "Graduation Percentage"]]

# %%
X.head()
# Out:
#    SSC Percentage  HSC Percentage  Graduation Percentage
# 0            85.6            69.7                   60.7
# 1            82.0            62.0                   40.0
# 2            80.0            63.1                   56.1
# 3            76.0            64.0                   59.4
# 4            78.0            69.0                   57.9

# %%
y = df["Salary"]

# %%
y.head()
# Out:
# 0    47000
# 1    25647
# 2    38100
# 3    39456
# 4    41050
# Name: Salary, dtype: int64

# %% [markdown]
# ## Creating a simple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Saving model to disk

# %%
pickle.dump(reg, open("model.pkl", "wb"))

# %% [markdown]
# ## Let's try and check a prediction from our model

# %%
model = pickle.load(open("model.pkl", "rb"))

# %%
print(model.predict([[85.6,69.7,60.77]]))
# Out:
# [24693.84805492]
